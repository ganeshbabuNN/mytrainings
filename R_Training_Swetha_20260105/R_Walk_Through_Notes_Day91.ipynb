# %%
library(tidyverse)
library(nycflights13)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.3     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package to force all conflicts to become errors
# Warning messages:
# 1: package ‘tidyverse’ was built under R version 4.5.2
# 2: package ‘ggplot2’ was built under R version 4.5.3
# 3: package ‘tibble’ was built under R version 4.5.2
# 4: package ‘tidyr’ was built under R version 4.5.2
# 5: package ‘readr’ was built under R version 4.5.2
# 6: package ‘purrr’ was built under R version 4.5.2
# 7: package ‘dplyr’ was built under R version 4.5.2
# 8: package ‘stringr’ was built under R version 4.5.2
# ...

# %%
#handle txt files
# .csv and .tsv
setwd("C:\\Users\\ganes\\Downloads\\R_test\\testing")

# %%
#Handling APIs/REST Data Import in R
library(httr)
library(jsonlite)
library(nycflights13)
library(tidyverse)
# Out:
# Warning message:
# package ‘httr’ was built under R version 4.5.3
# Attaching package: ‘jsonlite’
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
# Warning message:
# package ‘jsonlite’ was built under R version 4.5.3

# %%
response <- GET(
  "https://api.data.gov.sg/v1/environment/air-temperature"
)
status_code(response)
content_text<- content(response,as='text')
json_data<-fromJSON(content_text)
as_tibble(json_data)
# Out:
# No encoding supplied: defaulting to UTF-8.
# # A tibble: 3 × 3
#   metadata     items$timestamp           $readings    api_info
#   <named list> <chr>                     <list>       <named list>
# 1 <df [1 × 4]> 2026-05-22T23:40:00+08:00 <df [1 × 2]> <chr [1]>
# 2 <chr [1]>    2026-05-22T23:40:00+08:00 <df [1 × 2]> <chr [1]>
# 3 <chr [1]>    2026-05-22T23:40:00+08:00 <df [1 × 2]> <chr [1]>

# %%
#handling the SAS/SPSS/STat files in R
#reading SAS file
#reading xpt files
#writing the xpt files.

library(haven)
# Out:
# Warning message:
# package ‘haven’ was built under R version 4.5.3

# %%
#.sas7bdat
read_sas("AE.sas7bdat")

# %%
flight_data<-flights |> select(year,month,day,dep_time,dep_delay) |> slice(1:10)
write_xpt(flight_data,"flights.xpt")

# %%
read_xpt("flights.xpt")
# Out:
# # A tibble: 10 × 5
#     year month   day dep_time dep_delay
#    <dbl> <dbl> <dbl>    <dbl>     <dbl>
#  1  2013     1     1      517         2
#  2  2013     1     1      533         4
#  3  2013     1     1      542         2
#  4  2013     1     1      544        -1
#  5  2013     1     1      554        -6
#  6  2013     1     1      554        -4
#  7  2013     1     1      555        -5
#  8  2013     1     1      557        -3
#  9  2013     1     1      557        -3
# 10  2013     1     1      558        -2

# %%
#parquet files and arrow files its in big data files

library(arrow)
# Out:
# Attaching package: ‘arrow’
#
# The following object is masked from ‘package:lubridate’:
#
#     duration
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
# Warning message:
# package ‘arrow’ was built under R version 4.5.3

# %%
write_parquet(flights,"clean_flights.parquet")
read_parquet("clean_flights.parquet")
# Out:
# # A tibble: 336,776 × 19
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
#  1  2013     1     1      517            515         2      830            819
#  2  2013     1     1      533            529         4      850            830
#  3  2013     1     1      542            540         2      923            850
#  4  2013     1     1      544            545        -1     1004           1022
#  5  2013     1     1      554            600        -6      812            837
#  6  2013     1     1      554            558        -4      740            728
#  7  2013     1     1      555            600        -5      913            854
#  8  2013     1     1      557            600        -3      709            723
#  9  2013     1     1      557            600        -3      838            846
# 10  2013     1     1      558            600        -2      753            745
# ...

# %%
write_parquet(flights,"snappy_flights.parquet",compression = "snappy")
write_parquet(flights,"gzip_flights.parquet",compression = "gzip")
write_parquet(flights,"zstd_flights.parquet",compression = "zstd")
write_parquet(flights,"uncompressed_flights.parquet",compression = "uncompressed")

#uses 
#for big data
#faster than csv
#compresse
#it works with spark,hive,duckdB, cloud

# %%
#feather format
write_feather(flights,"flights.feather")
#extremely fast for local read/wrtie
#presevers types
#used for ML modeling
read_feather("flights.feather")
# Out:
# # A tibble: 336,776 × 19
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
#  1  2013     1     1      517            515         2      830            819
#  2  2013     1     1      533            529         4      850            830
#  3  2013     1     1      542            540         2      923            850
#  4  2013     1     1      544            545        -1     1004           1022
#  5  2013     1     1      554            600        -6      812            837
#  6  2013     1     1      554            558        -4      740            728
#  7  2013     1     1      555            600        -5      913            854
#  8  2013     1     1      557            600        -3      709            723
#  9  2013     1     1      557            600        -3      838            846
# 10  2013     1     1      558            600        -2      753            745
# ...

# %%
##
#THIS COMPLETES COMPLETE R
