# %%
library(tidyverse)
library(nycflights13)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package to force all conflicts to become errors
# Warning messages:
# 1: package ‘tidyverse’ was built under R version 4.5.2
# 2: package ‘ggplot2’ was built under R version 4.5.2
# 3: package ‘tibble’ was built under R version 4.5.2
# 4: package ‘tidyr’ was built under R version 4.5.2
# 5: package ‘readr’ was built under R version 4.5.2
# 6: package ‘purrr’ was built under R version 4.5.2
# 7: package ‘dplyr’ was built under R version 4.5.2
# 8: package ‘stringr’ was built under R version 4.5.2
# ...

# %% [markdown]
# #absoulte path
# #relative path
#
# C:\Kriyababa\GitHub\mytrainings\R_Training_Swetha_20260105\files

# %%
#IMPORT AND EXPORTS
library("readr")
#CSV files
#parquet, fst, feather,arrow()
getwd()
flights
write_csv(flights,"C:/Kriyababa/GitHub/mytrainings/R_Training_Swetha_20260105/files/flights.csv")

# %%
late_flights<- flights |> filter(arr_delay>60)
write_csv(late_flights,"files/late_flights.csv")

# %%
#temporary files
temp_file <- tempfile(fileext = ".csv")
write_csv(flights,temp_file)
temp_file

# %%
#na parameter
colSums(is.na(flights))
write_csv(flights,"files/flights_blank_na.csv",na="")
#replace Na ="Missing"
write_csv(flights,"files/flights_missing_na.csv",na="missing")

# %%
#Append paraemter
jan_flights <- flights |> filter(month==1)
feb_flights <- flights |> filter(month==2)
write_csv(jan_flights,"files/monthly_flights.csv")
write_csv(feb_flights,"files/monthly_flights.csv",append = TRUE)

# %%
#col_names
write_csv(late_flights,"files/with_headers.csv",col_names = TRUE)
write_csv(late_flights,"files/without_headers.csv",col_names = FALSE)

# %%
#Quote paraemter
write_csv(late_flights,"files/quote_needed.csv",quote="needed")
write_csv(late_flights,"files/quote_all.csv",quote="all")
write_csv(late_flights,"files/quote_none.csv",quote="none")

#none-some of the regional setting rejects quotes.
#needed- quote when it needed.

# %%
#escape 
airports_1 <-airports |> slice(1:5) |> mutate(
    remarks = c(
      'Pilot said "Delayed due to weather"', #'Pilot said ""Delayed due to weather"" '
      'Passenger said "Very good flight"',
      "Path: C:\\Flights\\Logs",
      'Quote and slash: "Error\\Warning"',
      'Normal text'
    )
  )
write_csv(airports_1,"files/orginal_escape.csv")
write_csv(airports_1,"files/double_escape.csv",escape = "double")
write_csv(airports_1,"files/backslash_escape.csv",escape = "backslash") # \
# Out:
# # A tibble: 5 × 9
#   faa   name                           lat   lon   alt    tz dst   tzone remarks
#   <chr> <chr>                        <dbl> <dbl> <dbl> <dbl> <chr> <chr> <chr>
# 1 04G   Lansdowne Airport             41.1 -80.6  1044    -5 A     Amer… "Pilot…
# 2 06A   Moton Field Municipal Airpo…  32.5 -85.7   264    -6 A     Amer… "Passe…
# 3 06C   Schaumburg Regional           42.0 -88.1   801    -6 A     Amer… "Path:…
# 4 06N   Randall Airport               41.4 -74.4   523    -5 A     Amer… "Quote…
# 5 09J   Jekyll Island Airport         31.1 -81.4    11    -5 A     Amer… "Norma…

# %%
#num_threads 
readr_threads()
#single thread.
write_csv(flights,"single_thread.csv",num_threads = 1)
write_csv(flights,"multi_thread.csv",num_threads = 4)

# %%
#Export Delayed Flights Report
#Export Carrier Summary Report
#Daily Automated Export of flights
#Export the top 100 longest flights.
