# %%
#Enclosing Scope

def vechicle(): #parent function
  front="start"

  def car(): #child functions
    model="Suzuki"
    print(front)
    print(model)

  car() #this is under parent funcions 

vechicle()# this sort enclospse
# Out:
# start
# Suzuki
