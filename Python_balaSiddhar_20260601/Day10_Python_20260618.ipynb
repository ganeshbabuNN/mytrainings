# %%
#frozen set
# read only part
a = {2,3,4,5,6,6,5}
a
f=frozenset(a)
type(f)

f
f.remove(6)
# Out:
# KeyboardInterrupt

# %%
s = set(f)
type(s)
s
s.remove(4)
s
# Out:
# {2, 3, 5, 6}

# %%
#Basic data types int,float,bool,string
#advanced data types or data structure list,tuple,set,frozenset, dictioners
#dictionary
#{key,value}
#create
dollars = {}

#adding the key and value = country, dollars
type(dollars)
dollars = {
    "India":86,
    "USA":102,
    "Swiss":33,
    "dum":[2,3,4,5,6]
}

#reading by keys
dollars["USA"]
dollars["India"]
#via index
dollars["dum"][2]
dollars["dum"][3]
dollars["USA"]

#if you want the keys
dollars.keys()
dollars.values()

dollars
# Out:
# {'India': 86, 'USA': 102, 'Swiss': 33, 'dum': [2, 3, 4, 5, 6]}
