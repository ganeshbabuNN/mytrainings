# %%
# Operator

# +, - ,* ...

#Different types
#Arithmetic operator
#Comparision operators
#Assignment Operators
#Logical Operators
#Bitwise operators
#membership operators
#idenity operator

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Arithmetic operator
a=2
b=5
c=3
print("Addition",a+b) #a & b are operand and + is operator
print("Substrations",a-b)
print("Division",a/b)
print("Mulitplications",a*b)
print("modulus operator",a%b) #reminder
print("modulus operator1",2%5) #reminder
print("modulus operator2",4%5) #reminder
print("Exponent operator",a**b)
print("Floor operator",b//c) # 1.23
print("Floor operator1",-5//2)
print("Floor operator2",5//2)
# Out:
# Addition 7
# Substrations -3
# Division 0.4
# Mulitplications 10
# modulus operator 2
# modulus operator1 2
# modulus operator2 4
# Exponent operator 32
# Floor operator 1
# Floor operator1 -3
# Floor operator2 2

# %%
#Comparison operator
a=2
b=2
c=3
print("Equal to:",a==b) #a & b are operant and + is operator
print("Not Equal to:",a!=b)
print("Less then equal to:",a<=b)
print("Greater then equal to: ",a>=b)
print("Greater Operator:",a>b) #reminder
print("Lesser Operator:",a<b)
# Out:
# Equal to: True
# Not Equal to: False
# Less then equal to: True
# Greater then equal to:  True
# Greater Operator: False
# Lesser Operator: False

# %%
#assignment operator
a=2
print("Assignment operator",a)
a+=3 
print("Plus and equal to operator",a)
a-=3
print("minus and equal to operator",a)
a*=3
print("multipple and equal to operator",a)
a**=3
print("exponent operator",a)
a//=3
print("floor and equal operator",a)
# Out:
# Assignment operator 2
# Plus and equal to operator 5
# minus and equal to operator 2
# multipple and equal to operator 6
# exponent operator 216
# floor and equal operator 72

# %%
a=2-3
a
# Out:
# -1
