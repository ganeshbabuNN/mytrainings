# %%
a =[1,1,2,2,3,3]
type(a)
a
# Out:
# [1, 1, 2, 2, 3, 3]

# %%
#Set
#creating the set
a ={"a","b",1,2,3}
a #ordering , removes duplicates

#reading - indexing 
#a[0] #indexing
#a[0:3] #slicings

if "a" in a:
    print("founded")

#iterate
#x is identifier
for bala in a:
    print(bala)


#update
#add a elemetn
a.add("bala") #adding
a
a.update(["DD","EE","FF"]) #multiple values
a

#deleteing
a
a.remove("DD")
a
a.discard("EE")
a
a.pop()
a
a.clear()
a

#list is not ordering, allow duplicates where set allows order and removes duplicates, 
#CRUD = create , read , update and delete
# Out:
# founded
# 1
# 2
# 3
# b
# a
# set()
