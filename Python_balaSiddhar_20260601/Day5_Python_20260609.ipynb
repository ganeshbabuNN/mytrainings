# %%
#Scope means

#local scope
a=10 #global scope
def sum():
    a=50 #local scope
    print(a)

sum()
# Out:
# 10

# %%
#Global scope
a=10 #global scope
def sum():
    print(a)

sum()
# Out:
# 10

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
def sum(a,b):
    print(a+b)

# %%
sum(5,3)
# Out:
# 8

# %%
def vehicle():
  fun= "Start"
    def car():
      model= "Toyota"
      print(fun)
      print(model)
      car()
    
vehicle()
# Out:
#   Cell In[1], line 4
#     def car():
#     ^
# IndentationError: unexpected indent
