# %%
# store a data in a python program = Varibales

a=2
print(a)
a #only in the notebbok
#for that dynamically typed language.. where variable not required define.
print(id(a))
#compiler and interpecter ## compiler checks the intex and interpecter the program # python memoery heap and stack
type(a)
a=10
print(id(a))
# Out:
# 2
# 140737039133144
# 140737039133400

# %%
a=10  #int
print(type(a))
a=10.88  #float
print(type(a))
a=True #boolean
print(type(a))
a=False #boolean
print(type(a))
a="ganesh" #string
print(type(a))
a='ganesh' #string
print(type(a))
#data type chapert
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>
# <class 'str'>
# <class 'str'>

# %%
# assignment 
a=10
b=10
c=10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %%
#multiple assignment
a=b=c=10
print(a)
print(b)
print(c)
# Out:
# 10
# 10
# 10

# %%
a,b,c=3,4,6
print(a)
print(b)
print(c)
# Out:
# 3
# 4
# 6

# %%
#rules of variable
#3a=10 cannot start with a number
#a b=10 cannot space
#a$b=b special character
_a=10
#def=10 #cannot use keywords
# Out:
#   Cell In[30], line 6
#     def=10
#        ^
# SyntaxError: invalid syntax
