# %%
#python Datascience

#Code editor
#VS code
#pycharm
#notebook - generally prototyping

#environment
#anaconda

# %%
print "hello world" # python 2.0
# Out:
#   Cell In[4], line 1
#     print "hello world" # python 2.0
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
#directly a command
print("Hello world") #python 3.x
# Out:
# Hello world

# %%
#using function way
def show(): #function show()
    print("Hello world")

# %%
show() #calling a functions
# Out:
# Hello world

# %%
# using the class way i,e Oops - object oriented programming
class show:
    def __init__(Self):
        print("Hello world")
    def display(self):
        print("Hello world2")

# %%
#1.create the object
a=show()  #once the object is created init() method is called automatically.
a.display()

#create a new object
a1=show()
a1.display()
# Out:
# Hello world
# Hello world2
# Hello world
# Hello world2
