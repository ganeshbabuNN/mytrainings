# %%
#mutable and immutable of an object reuseablity.

#immutable objects are which cannot be changed after it is created i,e different memory address.
#ex: int ,float, bool, string..tuple...
x = 10
print(id(x))
x= 11
x= 10
print(id(x))

#mutable.. address wil not change
#strings, list, dict.set ...etc 
s1="bala"
s1="ganesh"
print(id(s1))
s2="bala"
print(id(s2))
#s2="aksita"
# Out:
# 140706989828824
# 140706989828824
# 1482689722000
# 1482689860960

# %%
# data types string,int, bool, float,NaN
x=1
x=2
#when you store a single value to a object is called simple data types or normal
#when you store a more then a single value to a object is called sequence types or array.
x=3,2,4,5
print(type(x))
#string, list,tuple,byte, range are types of sequences types

#list
#object = []
##creating
#-------
x=[1,"gan",True,23.2,None,22,34,356,789,54]
print(type(x))

#reading
#---------
#indexing
x[1]
#slicing
x[1:4]
x[1:8:2]
x=[4,5]
#repeatition operator
x * 2
#concation
y=["x","y"]
x+y

#updating
#--------
x[0] = 8 #modify
x
x.append(6)
x
x.insert(3,"bala")  #based on position
x

#delete
x.remove("bala") #based on value
x.pop(0) #based on poisition
x
# Out:
# <class 'tuple'>
# <class 'list'>
# [5, 6]

# %%
#tuple
#it same has list
#syntax
# x=()

#create
x=(1,2,3)
type(x)
#x.insert("ganesh")
#x.append("gan")

#read
x[1] #indexing
x[0:2]

#update
#x[1]=9

#delete
#x.remove(1)

#tuple is nothing same has list but it is only read-only
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
#range
#sytax
#range(upplimt,lowerlimit)

for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
